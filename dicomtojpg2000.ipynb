# %%
! pip install -qU "python-gdcm" pydicom pylibjpeg "opencv-python-headless" "scikit-image" "ipywidgets" "dicomsdl"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 97.9 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 15.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.

# %%
# 1. Handle datasets
import io
import os
import cv2
import imageio
import pydicom
import dicomsdl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from glob import glob
import tifffile as tiff
import SimpleITK as sitk
from pathlib import Path
from tqdm.auto import tqdm
import multiprocessing as mp
from collections import Counter
from joblib import Parallel, delayed
from pydicom.pixel_data_handlers.util import apply_voi_lut

# %%
RESIZE_TO = 512
SAVE_DIR = f"/kaggle/working/train_image_processed_jp2000_{RESIZE_TO}"
parent_dir = "/kaggle/input/rsna-breast-cancer-detection"

# create the top-level folder
os.makedirs(SAVE_DIR, exist_ok=True)

# Gather all .dcm paths
all_dcm_files = list(Path(os.path.join(parent_dir, "train_images")).rglob("*.dcm"))
fail_counter = Counter()

def image_resize(image, width = None, height = None, inter = cv2.INTER_LINEAR):
    
    dim = None
    (h, w) = image.shape[:2]
    
    if width is None and height is None:
        return image

    if width is None:
        r = height / float(h)
        dim = (int(w * r), height)
    else:
        r = width / float(w)
        dim = (width, int(h * r))
    
    resized = cv2.resize(image, dim, interpolation=inter)
    return resized

def apply_window(image, window_center, window_width):
    img = image.copy().astype(np.float32)
    min_val = window_center - window_width / 2
    max_val = window_center + window_width / 2
    img = np.clip(img, min_val, max_val)
    img = (img - min_val) / (max_val - min_val)
    return img

def dicom_file_to_array(path):
    dicom = dicomsdl.open(str(path))
    data = dicom.pixelData().astype(np.float32)
    photometric = dicom.getPixelDataInfo()['PhotometricInterpretation']  # Cache this once
    
    if photometric == "MONOCHROME1":
        data = data.max() - data
    
    # ===== Windowing =====
    try:
        center = dicom.getMeta("0028|1050")  # Window Center
        width = dicom.getMeta("0028|1051")   # Window Width
        
        if isinstance(center, list):
            center = float(center[0])
        else:
            center = float(center)
        
        if isinstance(width, list):
            width = float(width[0])
        else:
            width = float(width)
        
        data = apply_window(data, center, width)
        
    except Exception:
        # Fall back to default normalization if window info is missing
        data = (data - data.min()) / (data.max() - data.min())

    # Resize    
    h, w = data.shape
    if w > h:
        data = image_resize(data, width=RESIZE_TO)
    else:
        data = image_resize(data, height=RESIZE_TO)
    
    return (data * 255).astype(np.uint8)

def process(path):
    try:
        parent_folder = path.parent.name
        save_subdir = os.path.join(parent_dir, SAVE_DIR, parent_folder)
        os.makedirs(save_subdir, exist_ok=True)

        processed_img = dicom_file_to_array(path)
        save_path = os.path.join(save_subdir, f"{path.stem}.jp2")
        imageio.imwrite(save_path, processed_img, format='JP2')

    except Exception as e:
        print(f"[ERROR] Failed: {path} — {e}")
        fail_counter["fail"] += 1

# Process with tqdm and joblib
Parallel(n_jobs=16, backend="loky", prefer="threads")(
    delayed(process)(path) for path in tqdm(all_dcm_files, 
                                            total=len(all_dcm_files))
)

print(f"✅ Done! Processed {len(all_dcm_files)} images.")
print(f"❌ Failed: {fail_counter['fail']}")
# Out:
#   0%|          | 0/54706 [00:00<?, ?it/s]
# ✅ Done! Processed 54706 images.
# ❌ Failed: 0

# %%
def open_jpeg2000_image(image_path):
    # Read the JPEG2000 image using OpenCV
    img = plt.imread(image_path)
    
    plt.imshow(img, cmap="turbo")
    plt.axis('off')
    plt.show()

# Example usage
image_path = os.path.join(SAVE_DIR, "105", "397491913.jp2")
if os.path.exists(image_path):
    open_jpeg2000_image(image_path)
else:
    print("False")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/3271880888.py in <cell line: 0>()
#       8
#       9 # Example usage
# ---> 10 image_path = os.path.join(SAVE_DIR, "105", "397491913.jp2")
#      11 if os.path.exists(image_path):
#      12     open_jpeg2000_image(image_path)
#
# NameError: name 'os' is not defined

# %%
# zip up your processed JP2 folder
# !zip -r /kaggle/working/processed_jp2.zip /kaggle/working/train_image_processed_jp2000_512
# Out:
#   adding: kaggle/working/train_image_processed_jp2000_512/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65014/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65014/1682583821.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65014/452541249.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65014/799096922.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65014/1035271497.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5188/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5188/287761314.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5188/520900873.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5188/1528865269.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5188/533898547.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30324/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30324/1657423416.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30324/359285820.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30324/1527871215.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30324/407579397.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30324/1287688434.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55731/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55731/48000782.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55731/1805409129.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55731/875849857.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55731/1030074623.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5748/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5748/728607250.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5748/1615160810.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5748/1454474858.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5748/1537302743.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38571/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38571/1587127230.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38571/1281685733.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38571/646631209.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38571/1711736849.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38571/1289924620.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38571/1477611477.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42559/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42559/215265457.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42559/2105345871.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42559/963204586.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42559/822217849.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/45083/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/45083/1133569856.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/45083/1596983929.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/45083/2129533813.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/45083/1328785581.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41508/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41508/2126863704.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41508/1345969487.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41508/379727704.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41508/931706113.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30187/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30187/306490013.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30187/1818480601.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30187/562081663.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30187/63266771.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41967/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41967/1665207903.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41967/1362666695.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41967/346138451.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41967/2033708519.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41967/816175133.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25906/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25906/523250783.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25906/806877649.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25906/933888739.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25906/91217771.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25906/465020534.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2606/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2606/477871193.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2606/230673267.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2606/1243766254.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2606/72547626.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2606/824029134.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2606/1300332380.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/19081/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/19081/145575893.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/19081/909108886.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/19081/1115039133.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/19081/960131174.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38400/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38400/181678988.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38400/1683370801.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38400/1428056364.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38400/1354952944.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38400/491443883.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/1956927015.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/156021109.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/167999868.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/525646440.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/927387157.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/951384262.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/822885011.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/1210993418.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/288754164.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/848824420.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/156885275.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/3280/49198902.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/44971/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/44971/1565715048.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/44971/1836581191.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/44971/1265019959.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/44971/853775751.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2290/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2290/1803805719.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2290/972192716.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2290/386573728.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2290/372492313.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22206/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22206/310424847.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22206/1953231213.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22206/937143512.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22206/35857619.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29927/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29927/249058752.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29927/805416872.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29927/2061844028.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29927/1109684443.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29927/1247551926.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29927/68491.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/49345/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/49345/1199393336.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/49345/1739574246.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/49345/1746978626.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/49345/1483220025.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15698/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15698/1309574083.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15698/2084655001.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15698/1262646758.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15698/812859243.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37769/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37769/1694541709.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37769/1641057901.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37769/1745096906.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37769/1252345521.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43563/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43563/42241328.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43563/1180612222.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43563/916133605.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43563/212890197.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43563/345881881.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43563/1188709876.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/8536/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/8536/214830194.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/8536/598332994.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/8536/1201536911.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/8536/2039614896.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16133/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16133/725989616.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16133/763798760.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16133/1804876621.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16133/674344482.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/62100/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/62100/1778163744.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/62100/953857949.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/62100/1291967324.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/62100/1021049485.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/62100/1968177567.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46710/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46710/42949692.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46710/604371948.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46710/434707629.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46710/302014986.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63536/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63536/1883381614.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63536/1482748953.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63536/1361981126.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63536/1354875298.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21863/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21863/140158412.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21863/561626054.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21863/1094863283.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21863/22720331.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15923/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15923/1064098879.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15923/1271604379.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15923/873692485.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/15923/1544283669.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/56563/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/56563/336296003.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/56563/872532507.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/56563/1714997620.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/56563/178418000.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/18498/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/18498/1993763544.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/18498/121786153.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/18498/601660898.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/18498/1056979650.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59592/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59592/219576575.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59592/1519186712.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59592/1270509112.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59592/283931329.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50379/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50379/1719458036.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50379/1825553702.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50379/937980350.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50379/1594209534.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5016/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5016/1004218495.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5016/1676931384.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5016/893291103.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5016/469327227.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/883858254.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/2073458503.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/2048900690.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/981389635.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/893341790.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/1667623374.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/16699/2112754059.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34215/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34215/402632684.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34215/1319372644.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34215/583969798.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34215/1710972357.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21468/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21468/443577437.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21468/11913693.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21468/598419911.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21468/1212754999.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25538/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25538/1608814541.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25538/1944203904.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25538/1922513800.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25538/1408139656.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/1602793376.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/1847998717.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/1256209009.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/65632399.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/812707999.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/61748476.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47404/511460565.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30074/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30074/300532988.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30074/530636080.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30074/507537956.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30074/1625232223.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/4129/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/4129/2010738508.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/4129/6860346.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/4129/1001807729.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/4129/1936733454.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65197/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65197/1522805039.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65197/1007838987.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65197/1365535574.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65197/1332620685.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50924/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50924/1202340386.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50924/88189449.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50924/669654663.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50924/871829660.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47466/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47466/288432772.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47466/1340469140.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47466/945040152.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47466/1354105164.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42415/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42415/655414501.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42415/796791825.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42415/1072372501.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42415/1376159355.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/703/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/703/1871341139.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/703/1796536763.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/703/1720214382.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/703/557656938.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/703/1458471363.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/703/1124901329.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2704/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2704/166586882.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2704/13617842.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2704/566928744.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2704/2017924690.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2704/781524556.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30977/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30977/1230736508.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30977/1666336141.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30977/1239103734.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/30977/428127330.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26086/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26086/2093532708.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26086/250987349.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26086/252109362.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26086/1640896163.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61668/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61668/971266222.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61668/602049208.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61668/1739982245.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61668/198923768.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61668/1931672296.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61668/1521138032.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42529/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42529/87204244.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42529/1850418461.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42529/899308950.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42529/1639892937.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48281/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48281/909789183.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48281/1877165514.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48281/1139049292.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48281/208147431.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/52587/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/52587/17947919.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/52587/2056496799.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/52587/521005838.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/52587/1392657567.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26011/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26011/1431340100.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26011/300565447.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26011/2043719141.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/26011/380619882.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9965/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9965/1229053771.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9965/69676487.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9965/1990076391.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9965/1523807232.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21431/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21431/83297018.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21431/1267661046.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21431/2124992327.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21431/743492847.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10526/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10526/880953279.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10526/1782974695.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10526/657541655.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10526/1505027709.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10526/376934385.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41240/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41240/1123624146.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41240/1483131482.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41240/1125439820.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41240/459302779.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41240/1869401422.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41240/608065348.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29192/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29192/1818973308.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29192/5002218.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29192/1434494645.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29192/891664732.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29192/1094259585.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29192/1799518934.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24405/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24405/2049346948.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24405/414478013.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24405/1052676283.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24405/1401897568.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61491/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61491/1921481913.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61491/1256640697.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61491/1204079480.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61491/11425212.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58202/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58202/58049296.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58202/638619075.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58202/355211916.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58202/1123015644.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55029/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55029/1932279989.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55029/1920122181.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55029/230240854.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/55029/2109687671.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10208/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10208/74874399.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10208/638273415.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10208/1922025927.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10208/1248063999.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20583/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20583/1346629986.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20583/216250015.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20583/187834508.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20583/1229039638.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17500/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17500/532902636.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17500/1375679600.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17500/1860610374.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17500/2103414182.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24584/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24584/859639855.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24584/765777879.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24584/1896824711.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24584/1352483459.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/24584/1260636918.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/1352/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/1352/1163841121.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/1352/259996195.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/1352/1182869663.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/1352/580300926.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63569/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63569/1622898592.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63569/268656542.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63569/1075642364.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63569/622628264.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11542/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11542/737651678.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11542/185407699.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11542/1608546074.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11542/1609873402.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38402/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38402/64466454.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38402/185370641.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38402/1228067442.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/38402/1948224966.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54099/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54099/1719971437.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54099/841894624.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54099/1260101829.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54099/1868125273.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10445/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10445/215007914.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10445/224398130.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10445/38118563.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/10445/1559303163.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37106/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37106/686421885.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37106/1490667012.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37106/295676489.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/37106/1164344717.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58385/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58385/413007120.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58385/1530140465.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58385/48013998.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/58385/1345806153.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/656330523.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/1603828499.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/1870570286.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/1804333793.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/1494457072.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/137087280.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/2067448009.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/914840750.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/583621111.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21744/5186053.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5306/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5306/1780873099.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5306/459023633.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5306/1602806539.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/5306/973146534.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46455/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46455/1472824422.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46455/708109743.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46455/1717446638.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46455/1745523061.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/46455/1114373597.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47008/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47008/721134672.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47008/1393683353.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47008/2108029802.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47008/1460743664.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47008/283111213.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/47008/955899974.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48596/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48596/163975340.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48596/1683210912.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48596/197548465.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48596/317527744.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/48596/844917725.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17808/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17808/1431788631.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17808/797829458.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17808/95636018.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17808/2075516041.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17808/97569529.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43836/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43836/1471069029.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43836/928610054.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43836/562534699.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43836/1099025943.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59191/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59191/1559238444.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59191/715454989.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59191/17993946.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59191/1279064615.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59191/1212956108.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59191/1361207416.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25161/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25161/1531947883.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25161/1517455091.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25161/113618729.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/25161/136826382.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17375/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17375/336280988.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17375/956115140.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17375/757752429.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17375/995941712.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17375/1713085755.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54839/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54839/301384548.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54839/1248558144.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54839/1670950003.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54839/924079527.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/23375/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/23375/785541547.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/23375/173293257.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/23375/1409979590.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/23375/432210619.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/23375/1535644215.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/23375/154794478.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20751/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20751/888580577.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20751/1583024467.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20751/1329881532.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20751/595439207.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/7033/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/7033/2071257818.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/7033/559538557.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/7033/1961292782.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/7033/91555108.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/7033/1442262040.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/804642443.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/1998024633.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/469442434.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/285476020.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/144509956.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/2079544503.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/171066332.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50039/1417663663.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34855/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34855/222315332.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34855/1559623893.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34855/459790749.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34855/1873599306.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65003/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65003/1551646735.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65003/135026824.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65003/648340609.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/65003/502379724.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/6687/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/6687/657150020.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/6687/615787358.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/6687/1699953089.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/6687/231911037.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/6687/1431742087.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/6687/704347321.jp2 (deflated 0%)
# ...
#   adding: kaggle/working/train_image_processed_jp2000_512/17216/1779511585.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17216/817922289.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/13870/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/13870/2131561831.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/13870/1842220249.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/13870/174685247.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/13870/46089792.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/13870/707256663.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2288/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2288/1271101618.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2288/1007669362.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2288/532180287.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/2288/1795005889.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/1179030495.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/1461698215.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/788873630.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/424357269.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/1267687959.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/579976044.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/1651509574.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/793467464.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/270859336.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/14004/832730327.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63453/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63453/957012839.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63453/2126290731.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63453/725012666.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/63453/222008027.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43429/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43429/1395352646.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43429/336428397.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43429/626215624.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43429/1972885308.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/43429/1381098029.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/12718/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/12718/1526215300.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/12718/1435103117.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/12718/384702285.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/12718/228062348.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/33719/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/33719/1474670582.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/33719/168941800.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/33719/177138270.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/33719/235404498.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/33719/2087709433.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29598/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29598/2128603347.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29598/350357933.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29598/1984994348.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/29598/1007476861.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/31804/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/31804/1524066186.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/31804/1302174032.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/31804/976231776.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/31804/217002459.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17367/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17367/1526715267.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17367/1814818723.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17367/1140828704.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/17367/1182019416.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/54042579.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/1674234383.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/2051272841.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/327342669.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/1415178698.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/2128026498.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/1770994656.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/11405/518009807.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41564/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41564/1629591630.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41564/801168862.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41564/562465839.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/41564/351638250.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/27925/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/27925/1624680784.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/27925/1020448478.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/27925/330845917.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/27925/1916192448.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54816/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54816/1770069930.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54816/1434814136.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54816/964512343.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54816/458427195.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/54816/435197796.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/734208388.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/20678794.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/110090345.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/1743182090.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/29235736.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/1142743347.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/1446615667.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/8017397.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/51627/114583784.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/318/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/318/938332062.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/318/438214368.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/318/1396263591.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/318/359724140.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/55649335.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/673014670.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/623666243.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/755332193.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/1701827688.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/1802610378.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/1580149536.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/38304149.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/689242650.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/34380/1132224329.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21318/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21318/1442144298.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21318/447164315.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21318/1099555184.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/21318/968305375.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61976/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61976/222246116.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61976/453795235.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61976/741428929.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61976/614013945.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/61976/457419005.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/57672/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/57672/622309546.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/57672/39212906.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/57672/1101908095.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/57672/620790580.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20655/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20655/621932397.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20655/386780840.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20655/1031782749.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/20655/778886489.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42125/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42125/440050899.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42125/457132376.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42125/557383005.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/42125/393387271.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9746/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9746/1396742958.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9746/983751012.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9746/1128044639.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/9746/1463315070.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22060/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22060/846218107.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22060/429934661.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22060/1790151672.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/22060/450955062.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/36196/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/36196/1528532804.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/36196/1451436890.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/36196/879296055.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/36196/1582114739.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59079/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59079/1283757926.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59079/1076928743.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59079/1808491999.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/59079/1070852388.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/763/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/763/1263517435.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/763/1592377737.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/763/1721849879.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/763/1797155020.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/32614/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/32614/2132053372.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/32614/1303963315.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/32614/1214547626.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/32614/2016537179.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50229/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50229/1286580847.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50229/1324334766.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50229/1296269818.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50229/10337454.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50843/ (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50843/1632908599.jp2 (deflated 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50843/442916102.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50843/1045154211.jp2 (stored 0%)
#   adding: kaggle/working/train_image_processed_jp2000_512/50843/1740076000.jp2

# %%
# !kaggle datasets init -p /kaggle/working/train_image_processed_jp2000_512
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 433, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
# !kaggle datasets create -p /kaggle/working/train_image_processed_jp2000_512
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 433, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
